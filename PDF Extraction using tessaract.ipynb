# %%
import re
import pdfplumber
from pdf2image import convert_from_path
from PIL import Image
from pytesseract import image_to_string
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
def convert_pdf_to_img(pdf_file):
    return convert_from_path(pdf_file, poppler_path= r'C:\\Users\\computer\\Downloads\\poppler-0.68.0_x86\\poppler-0.68.0\\bin')

def convert_img_to_text(file):
    text = pytesseract.image_to_string(file)
    return text

def get_text_from_any_pdf(pdf_file):
    images = convert_pdf_to_img(pdf_file)
    final_text = ""
    for pg, img in enumerate(images):
        final_text += convert_img_to_text(img)
    return final_text

# %%
path_to_pdf = "22NN16210.pdf"

# %%
print(get_text_from_any_pdf(path_to_pdf))
# Out:
# TTR Uifere Fret : HeTeTAT Wear Halt ay 2022
#
# OPT HATH (Ale et) : 10
#
# FAG Se SHH TAM: 910 - asa Vor Heat THs shay eT TM
#
# 4 TS HIM FA 34 F880 Ah 14 148
# 2 teal HE 149 8503
# 3 1 Sipe Us tet 504 & 667
#
# aot Gal F afeaferst Haararait Ht pot AST :
#
# qeq: 318 Hfeet: 349 667
#
# arya att F aftatera aera Ht GST :
#
# aT ce srrafecat & FRI USAT (STR Galt & STA WR)
# Get A enter Haar cal Set GT F aes aT AT
#
# ates (+) 0
# wat (-) 30
# WHA Tex a BA (4/-) : -30
# lar Gat F ener Hor Aare : 637
# ee WAV ARAJARIA
#
# Date? 2022/04/16 07:08:29
# am ules Frm : sacrae
#
# Re)
#
# als HAIG : 62 - aeaSsar aS art wmATH : 10
#
# aent Aas
#
# a grasa SH OA
#
# t
#
# ; aT
#
# ee il
#
# Digitally signed by
# PTS 30 Tye 2 IVAY ARAJARIA
# Date:2022/04/16 07:08:29
# are wai: 62 ǩ (saeTIR) aM weAie : 10
#
# 1 - 4 tart @retat FA Bu ST vo AH
#
# NZD1007285 NZD0989624 | _ 3]: NZD1033489
#
# i TEM wa 321
#
# Haaren rary: etateat set
# fra: ret at
#
# fort: afer ay: 22 ag
#
# |} __ 6] +NZD0415067
#
# ...
